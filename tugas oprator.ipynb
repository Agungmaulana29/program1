# %%
>>> 10+5
# Out:
# 15

# %%
>>> 5+1
# Out:
# 6

# %%
>>> 20-20
# Out:
# 0

# %%
>>> 45*46
# Out:
# 2070

# %%
>>> 6789/67
# Out:
# 101.32835820895522

# %%
>>> 10/4
# Out:
# 2.5

# %%
>>> 45**46
# Out:
# 11162864000310351547259213207793571038503876167169437394477427005767822265625

# %%
>>> 67//98
# Out:
# 0

# %%
45+13
# Out:
# 58

# %%
45-13
# Out:
# 32

# %%
a,b= 45,15

# %%
print(a,'+',b,'=',a>b)
print(a,'<',b,'=',a<b)
print(a,'==',b,'=',a==b)
print(a,'!=',b,'=',a!=b)
print(a,'<=',b,'=',a<=b)
# Out:
# 45 + 15 = True
# 45 < 15 = False
# 45 == 15 = False
# 45 != 15 = True
# 45 <= 15 = False

# %%
# penugasan pertama

# %%
a=10

# %%
print('a=10->',a)
# Out:
# a=10-> 10

# %%
a+=15

# %%
print('a+=15->',a)
# Out:
# a+=15-> 25

# %%
a-=8

# %%
print('a-=->',a)
# Out:
# a-=-> 25

# %%
a*=9

# %%
print('a*=->',a)
# Out:
# a*=-> 153

# %%
a/=34

# %%
print('a/=->',a)
# Out:
# a/=-> 4.5

# %%
#kerena a jadi float,kita ubah lagi menjadi integer

# %%
a=int(a)

# %%
a%=56

# %%
print('a//=->',a)
# Out:
# a//=-> 45

# %%
a**=5657

# %%
print('a **=5657',a)
# Out:
# a **=5657 45

# %%
perusahaan='perbukitan'
list_sumatra=['aceh','sumatera','jambi','lampung']

# %%
#ini adalah dictionary

# %%
murid={
'nama':'fahri ahmad',
'asal':'madura'
}

# %%
print("apakah 'c'ada di variabel perusahaan?",
      'c'not in perusahaan )
# Out:
# apakah 'c'ada di variabel perusahaan? True

# %%
print("apakah 'p'tidak ada di variabael perusahaan?",
      'c' in perusahaan)
# Out:
# apakah 'p'tidak ada di variabael perusahaan? False

# %%
print(
    # "apakah atribut'nama,ada di variabel murid?",
   'nama'in murid
)
# Out:
# apakah atribut'nama,ada di variabel murid? True

# %%
print(
    "apakah 'semarang' tidak ada di variabel list_sumatera?",
    'semarang' not in perusahaan
)
# Out:
# apakah 'semarang' tidak ada di variabel list_sumatera? True

# %%
a=45
b=67
nama_a='anton'
nama_b='budi'

# %%
#output true

# %%
print('a is b:',a is b)
# Out:
# a is b: False

# %%
#otput flase

# %%
print('a is not b:',a is not b)
# Out:
# a is not b: True

# %%
#output true

# %%
print('nama_a is nama_b:',nama_a is nama_b)
# Out:
# nama_a is nama_b: False

# %%
#output flase

# %%
print('nama_a is not nama_b:',nama_a is not nama_b)
# Out:
# nama_a is not nama_b: True

# %%
>>> id('merah')
# Out:
# 135311928921584

# %%
>>> id('merah')
# Out:
# 135311928960176

# %%
>>> id(23)
# Out:
# 135313200939952

# %%
>>> id (45)
# Out:
# 135313200940656
