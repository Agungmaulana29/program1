# %%
panjang = 67
lebar=34
luas = panjang * lebar

# %%
print("luas = ",luas)
# Out:
# luas =  2278

# %%
nama = input('masukan nama anda: ')

print('masukin nama anda:',type(nama))
# Out:
# masukan nama anda: agung
# masukin nama anda: <class 'str'>

# %%
print('kalkulator luas persegi \n:')
panjang=input('10: ')
lebar=input('5: ')
# Out:
# kalkulator luas persegi
# :
# 10: 10
# 5: 5
