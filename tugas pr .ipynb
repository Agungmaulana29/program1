# %%
#akses nilai tuple python

# %%
tp1=('setan','pocong','kunti',345,45,8)

# %%
tp2= (23, 34, 8, 9, 63)

# %%
tp3="ayam","kambing","kucing","cacing"

# %%
print("tuple 1[0]:",tp1[0])
# Out:
# tuple 1[0]: setan

# %%
print("tuple 2[0:3]:",tp2[0:5])
# Out:
# tuple 2[0:3]: (23, 34, 8, 9, 63)

# %%
print("tuple 1[2:4]:",tp3[2:3])
# Out:
# tuple 1[2:4]: ('kucing',)

# %%
#jadi,buatlah tuple baru

# %%
tp1=('setan','pocong','kunti',345,45,8)

# %%
tp2= (23, 34, 8, 9, 63)

# %%
tp3="ayam","kambing","kucing","cacing"

# %%
#tuple baru sebagai brikut

# %%
tp4=tp1+tp2

# %%
tp5=tp3+tp1

# %%
tp6=tp1+tp2+tp3

# %%
#hasil

# %%
print("tuple baru tp4",tp4)
# Out:
# tuple baru tp4 ('setan', 'pocong', 'kunti', 345, 45, 8, 23, 34, 8, 9, 63)

# %%
print("tuple baru tp6",tp6)
# Out:
# tuple baru tp6 ('setan', 'pocong', 'kunti', 345, 45, 8, 23, 34, 8, 9, 63, 'ayam', 'kambing', 'kucing', 'cacing')

# %%
print("tuple baru tp5",tp5)
# Out:
# tuple baru tp5 ('ayam', 'kambing', 'kucing', 'cacing', 'setan', 'pocong', 'kunti', 345, 45, 8)

# %%
tp1=('setan','pocong','kunti',345,45,8)

# %%
tp2= (23, 34, 8, 9, 63)

# %%
tp3="ayam","kambing","kucing","cacing"

# %%
#hapus tuple dengan statement del

# %%
del tp1

# %%
del tp2

# %%
del tp3

# %%
# lalu buat tuple yang di inginkan

# %%
tp1=('mangga','jeruk','murai',564)

# %%
tp2=('pupus','kelinci',54537,'kera')

# %%
tp3=('menu',"ayam penyet",47438,"ikan bakar",5545)

# %%
print("setelah menghapus tuple tp1:",tp1)
# Out:
# setelah menghapus tuple tp1: ('mangga', 'jeruk', 'murai', 564)

# %%
print("setelah menghapus tuple tp2:",tp2)
# Out:
# setelah menghapus tuple tp2: ('pupus', 'kelinci', 54537, 'kera')

# %%
print("setelah menghapus tuple tp3:",tp3)
# Out:
# setelah menghapus tuple tp3: ('menu', 'ayam penyet', 47438, 'ikan bakar', 5545)
